# %% [markdown]
# # Иерархия для Постнауки. Version 0.

# %%
import artm
import os
import glob
import sys

# %%
sys.path.append("D:/PTM/code/BigAltHier")

# %%
import hierarchy_utils
reload(hierarchy_utils)
# Out:
# <module 'hierarchy_functions' from 'D:/PTM/code/BigAltHier\hierarchy_functions.py'>

# %%
data_path_UCI = 'ngramm/pymorphy/UCI_trimmed/'
data_path_batches = 'ngramm/pymorphy/batches/'
if len(glob.glob(data_path_batches + "/*.batch")) < 1:
    batch_vectorizer = artm.BatchVectorizer(collection_name='postnauka', data_format='bow_uci', \
                data_path = data_path_UCI, batch_size = 200, target_folder=data_path_batches)
else:
    batch_vectorizer = artm.BatchVectorizer(data_path=data_path_batches, data_format='batches')

# %%
def get_topic_names(topicNum):
    """
    generates topic names
    """
    n_bckgrnd = 0
    n_subj = topicNum-n_bckgrnd
    topics_bckgrnd = [u'background_'+str(i).zfill(3) for i in range(n_bckgrnd)]
    topics_subj = [u'subj_'+str(i).zfill(3) for i in range(n_subj)]
    topic_names = topics_bckgrnd + topics_subj
    return topic_names

# %%
class_ids={'ngramm':1.0, 'projects':1.0, 'category':1, 'author': 5.0, 'post_tag':5.0}

# %%
regularizers_list = []

regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiCatReg',class_ids=['category'],tau=0.05))
regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiAuthorReg',class_ids=['author'],tau=0.05))
regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiTagReg',class_ids=['post_tag'],tau=0.05))
regularizers_list.append(artm.DecorrelatorPhiRegularizer(name='DecorrPhiReg',class_ids=['ngramm'],tau=50000))

regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiNgrammRegSubj',
                                                         class_ids=['ngramm'],
                                                         #topic_names=topics_subj,
                                                         tau=0.01))
regularizers_list.append(artm.SmoothSparseThetaRegularizer(name='SmoothThetaRegSubj',
                                                           #topic_names=topics_subj,
                                                           tau=0.01))

# %%
# quality measures of models
scores_list = []
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreNgrammSubj',
                                         class_id='ngramm',
                                         #topic_names=topics_subj
                                        ))
scores_list.append(artm.SparsityThetaScore(name='SparsityScoreThetaSubj',
                                           #topic_names=topics_subj
                                          ))

scores_list.append(artm.SparsityPhiScore(name='SparsityScoreCat', class_id='category'))
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreAuthor', class_id='author'))
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreTag', class_id='post_tag'))
scores_list.append(artm.TopTokensScore(name='TopTokensScoreNgramm', class_id='ngramm', num_tokens=10))
scores_list.append(artm.TopTokensScore(name='TopTokensTag', class_id='post_tag', num_tokens=10))
scores_list.append(artm.TopicKernelScore(name='TopicKernelNgramm', class_id='ngramm', probability_mass_threshold=0.25))
scores_list.append(artm.PerplexityScore(name='PerplexityScore', class_ids=['ngramm']))

# %%
dict_path = 'ngramm/pymorphy/UCI_trimmed/dictionary.txt'
if not os.path.isfile(dict_path):
    dictionary = artm.Dictionary('dictionary')
    dictionary.gather(batch_vectorizer.data_path)
    dictionary.save_text(dict_path)
else:
    dictionary = artm.Dictionary('dictionary')
    dictionary.load_text(dict_path)

# %% [markdown]
# ### Построение первого уровня (обыкновеная тематическая модель)

# %%
topicNum0 = 10
level0 = artm.ARTM(num_topics=topicNum0,
                  topic_names=get_topic_names(topicNum0),
                  class_ids=class_ids,
                  regularizers=regularizers_list,
                  scores=scores_list,
                  seed=37)
level0.initialize(dictionary=dictionary)

# %%
level0.fit_offline(batch_vectorizer, num_collection_passes=30)

# %%
tokens = level0.score_tracker["TopTokensTag"].last_tokens
for topic_name in level0.topic_names:
    print topic_name + ': ',
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# subj_000:  биология антропология эволюция человек история палеонтология антропогенез география геология археология
# subj_001:  физика астрономия астрофизика Вселенная звезды физика_элементарных_частиц галактика квантовая_физика космос черные_дыры
# subj_002:  культура социология общество массовая_культура город культурология философия кино искусство гендер
# subj_003:  биология медицина генетика ДНК ген клетка геном технологии микробиология химия
# subj_004:  история политика история_России право Россия Средневековье государство СССР политология Германия
# subj_005:  экономика история Россия США религия Европа государство христианство общество Китай
# subj_006:  философия социология образование наука Россия университет история_науки общество история_философии Кант_Иммануил
# subj_007:  психология мозг технологии информационные_технологии нейробиология биология нейрон когнитивная_психология нейрофизиология мышление
# subj_008:  математика физика Земля химия материаловедение Солнечная_система планета астрономия космос общая_теория_относительности
# subj_009:  язык лингвистика филология культура русский_язык литература история мифология литературоведение фольклор

# %% [markdown]
# ### Построение второго уровня (класс ARTM_Level)
# __Очень важно:__ при создании каждого уровня указывать новый seed (иначе дочерние темы начинают дублировать родительские)

# %%
topicNum1 = 30
level1 = hierarchy_functions.ARTM_Level(level0, phi_batch_weight=10.0**3, 
                                        num_topics=topicNum1, 
                                        topic_names=get_topic_names(topicNum1), 
                                         class_ids=class_ids,
                                          regularizers=regularizers_list,
                                           scores=scores_list,
                                            num_document_passes=1, 
                                             cache_theta=True, seed=124)

# %%
level1.initialize(dictionary=dictionary)
level1.fit_offline(batch_vectorizer, num_collection_passes=30)

# %%
tokens = level1.score_tracker["TopTokensTag"].last_tokens
for topic_name in level1.topic_names:
    print topic_name + ': ',
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# subj_000:  астрофизика астрономия черные_дыры звезды галактика Вселенная физика гравитация физика_элементарных_частиц нейтронные_звезды
# subj_001:  мозг нейробиология нейрон нейрофизиология память искусственный_интеллект психология физиология эмоции робототехника
# subj_002:  общество город Россия урбанистика искусство городское_пространство архитектура Москва культура социология_пространства
# subj_003:  астрономия космос Солнечная_система планета Солнце звезды Земля Вселенная галактика Марс
# subj_004:  образование наука университет история_науки школа академическая_среда социология_науки философия_науки Россия ЕГЭ
# subj_005:  культура массовая_культура культурология кино гендер кинематограф театр СССР идентичность театроведение
# subj_006:  физика Земля экзопланета материаловедение Эйнштейн_Альберт химия метеорит квантовая_механика история_науки марсоход
# subj_007:  физика Вселенная астрофизика космология астрономия космическая_инфляция реликтовое_излучение космос Большой_взрыв сверхпроводимость
# subj_008:  политика история история_России государство Германия Россия политология СССР политическая_философия Сталин_Иосиф
# subj_009:  информационные_технологии математика информатика технологии computer_science интернет компьютерное_моделирование социальные_сети информационная_безопасность машинное_обучение
# %%
tokens0 = level0.score_tracker["TopTokensTag"].last_tokens
tokens1 = level1.score_tracker["TopTokensTag"].last_tokens
for t, topic_name in enumerate(level0.topic_names):
    print topic_name + ': ',
    for word in tokens0[topic_name]:    
        print word,
    print
    for s, topic_name1 in enumerate(level1.topic_names):
        if psi.values[s, t] > 0.05:
            print "\t", topic_name1 + ': ',
            for word in tokens1[topic_name1]:    
                print word,
            print
# Out:
# subj_000:  биология антропология эволюция человек история палеонтология антропогенез география геология археология
# 	subj_011:  антропология человек антропогенез археология происхождение_человека Африка майя расоведение этнография неандерталец
# 	subj_016:  история Древняя_Греция античность христианство культура востоковедение нация миграция этнос мифология
# 	subj_022:  биология микробиология экология география микробы геология палеонтология биотехнологии бактерии климат
# 	subj_027:  биология эволюция зоология этология поведение_животных Дарвин_Чарльз эволюционная_биология теория_эволюции зоопсихология палеонтология
# subj_001:  физика астрономия астрофизика Вселенная звезды физика_элементарных_частиц галактика квантовая_физика космос черные_дыры
# 	subj_000:  астрофизика астрономия черные_дыры звезды галактика Вселенная физика гравитация физика_элементарных_частиц нейтронные_звезды
# 	subj_003:  астрономия космос Солнечная_система планета Солнце звезды Земля Вселенная галактика Марс
# 	subj_006:  физика Земля экзопланета материаловедение Эйнштейн_Альберт химия метеорит квантовая_механика история_науки марсоход
# 	subj_007:  физика Вселенная астрофизика космология астрономия космическая_инфляция реликтовое_излучение космос Большой_взрыв сверхпроводимость
# 	subj_020:  бозон_Хиггса физика_элементарных_частиц Стандартная_модель Большой_адронный_коллайдер элементарная_частица Россия общество симметрия коллайдер суперсимметрия
# 	subj_026:  физика квантовая_физика атом магнитное_поле квантовая_механика фотоны квантовые_технологии оптика электрон лазер
# subj_002:  культура социология общество массовая_культура город культурология философия кино искусство гендер
# 	subj_002:  общество город Россия урбанистика искусство городское_пространство архитектура Москва культура социология_пространства
# 	subj_005:  культура массовая_культура культурология кино гендер кинематограф театр СССР идентичность театроведение
# 	subj_019:  культура литература фольклор литературоведение интернет история фольклористика коммуникация общество Кавказ
# 	subj_024:  социология общество социология_повседневности Гоффман_Эрвинг Дюркгейм_Эмиль теория_фреймов Вебер_Макс Зиммель_Георг Латур_Брюно этнометодология
# subj_003:  биология медицина генетика ДНК ген клетка геном технологии микробиология химия
# 	subj_021:  ДНК геном биология ген генетика химия молекула биоинформатика молекулярная_биология РНК
# 	subj_022:  биология микробиология экология география микробы геология палеонтология биотехнологии бактерии климат
# 	subj_023:  биология медицина клетка генетика биомедицина онкология белки ген микробиология бактерии
# 	subj_025:  технологии медицина биология человек биоэтика старение смерть доказательная_медицина томография кровеносная_система
# subj_004:  история политика история_России право Россия Средневековье государство СССР политология Германия
# 	subj_008:  политика история история_России государство Германия Россия политология СССР политическая_философия Сталин_Иосиф
# 	subj_018:  история Средневековье право Европа христианство государство юриспруденция римское_право католицизм Рим
# 	subj_028:  история история_России СССР Франция политология Англия социология_права право демократия Французская_революция_XVIII_века
# subj_005:  экономика история Россия США религия Европа государство христианство общество Китай
# 	subj_002:  общество город Россия урбанистика искусство городское_пространство архитектура Москва культура социология_пространства
# 	subj_013:  история Россия религия Китай Русь Япония ислам экономика рынок демография
# 	subj_018:  история Средневековье право Европа христианство государство юриспруденция римское_право католицизм Рим
# 	subj_029:  экономика США Нобелевская_премия общество Россия экономическое_развитие финансовый_рынок экономическое_неравенство коррупция новая_институциональная_экономика
# subj_006:  философия социология образование наука Россия университет история_науки общество история_философии Кант_Иммануил
# 	subj_004:  образование наука университет история_науки школа академическая_среда социология_науки философия_науки Россия ЕГЭ
# 	subj_010:  философия история_философии Кант_Иммануил Платон марксизм Маркс_Карл этика Аристотель немецкая_классическая_философия аналитическая_философия
# 	subj_020:  бозон_Хиггса физика_элементарных_частиц Стандартная_модель Большой_адронный_коллайдер элементарная_частица Россия общество симметрия коллайдер суперсимметрия
# 	subj_024:  социология общество социология_повседневности Гоффман_Эрвинг Дюркгейм_Эмиль теория_фреймов Вебер_Макс Зиммель_Георг Латур_Брюно этнометодология
# 	subj_029:  экономика США Нобелевская_премия общество Россия экономическое_развитие финансовый_рынок экономическое_неравенство коррупция новая_институциональная_экономика
# subj_007:  психология мозг технологии информационные_технологии нейробиология биология нейрон когнитивная_психология нейрофизиология мышление
# 	subj_001:  мозг нейробиология нейрон нейрофизиология память искусственный_интеллект психология физиология эмоции робототехника
# 	subj_009:  информационные_технологии математика информатика технологии computer_science интернет компьютерное_моделирование социальные_сети информационная_безопасность машинное_обучение
# 	subj_017:  психология когнитивная_психология мышление сознание принятие_решений детство поведение_человека теория_принятия_решений сон психотерапия
# 	subj_025:  технологии медицина биология человек биоэтика старение смерть доказательная_медицина томография кровеносная_система
# subj_008:  математика физика Земля химия материаловедение Солнечная_система планета астрономия космос общая_теория_относительности
# 	subj_003:  астрономия космос Солнечная_система планета Солнце звезды Земля Вселенная галактика Марс
# 	subj_006:  физика Земля экзопланета материаловедение Эйнштейн_Альберт химия метеорит квантовая_механика история_науки марсоход
# 	subj_012:  химия нанотехнологии материаловедение наноматериалы миф углерод графен энергетика кристалл энергия
# 	subj_015:  математика кристаллография кристалл суперкомпьютеры топология логика геометрия материаловедение алгебра механика
# subj_009:  язык лингвистика филология культура русский_язык литература история мифология литературоведение фольклор
# 	subj_014:  язык лингвистика филология русский_язык мифология грамматика фольклористика полевая_лингвистика речь диалект
# 	subj_016:  история Древняя_Греция античность христианство культура востоковедение нация миграция этнос мифология
# 	subj_019:  культура литература фольклор литературоведение интернет история фольклористика коммуникация общество Кавказ

# %% [markdown]
# ### Построение третьего уровня

# %%
topicNum2 = 70
level2 = hierarchy_functions.ARTM_Level(level1, phi_batch_weight=10.0**3, 
                                        num_topics=topicNum2, 
                                        topic_names=get_topic_names(topicNum2), 
                                         class_ids=class_ids,
                                          regularizers=regularizers_list,
                                           scores=scores_list,
                                            num_document_passes=1, 
                                             cache_theta=True, seed=741)

# %%
level2.initialize(dictionary=dictionary)
level2.fit_offline(batch_vectorizer, num_collection_passes=30)

# %%
psi2 = level2.get_psi()

# %%
tokens2 = level2.score_tracker["TopTokensTag"].last_tokens
for topic_name in level2.topic_names:
    print topic_name + ': ',
    for word in tokens2[topic_name]:    
        print word,
    print
# Out:
# subj_000:  город урбанистика городское_пространство общество искусство архитектура Москва социология_пространства авангард искусствоведение
# subj_001:  клетка биология онкология стволовые_клетки клеточная_биология рак индуцированные_плюрипотентные_стволовые_клетки раковые_клетки регенеративная_медицина квантовая_химия
# subj_002:  эволюция биология этология зоология поведение_животных Дарвин_Чарльз эволюционная_биология зоопсихология теория_эволюции приматы
# subj_003:  США экономика социальная_структура финансовый_рынок безработица Нобелевская_премия Россия средний_класс рынок_труда экология
# subj_004:  Средневековье христианство юриспруденция римское_право католицизм Рим Европа право медиевистика история_права
# subj_005:  филология фольклористика фольклор поэзия народная_культура Скандинавия русская_литература коммуникация письменность литература
# subj_006:  Солнечная_система планета Солнце космос астрономия Марс экзопланета планеты Земля Юпитер
# subj_007:  материаловедение история_науки металлы химия изотоп кристалл 3D агрегатное_состояние_вещества фуллерены кибернетика
# subj_008:  Земля общая_теория_относительности Эйнштейн_Альберт специальная_теория_относительности Ньютон_Исаак метеорит Хокинг_Стивен теория_струн экзопланета марсоход
# subj_009:  физика физика_элементарных_частиц экзопланета симметрия кварк квантовая_теория_поля Эйнштейн_Альберт Стандартная_модель радиоактивность Фейнман_Ричард
# subj_010:  политология политика история_России идеология национализм государство либерализм культурная_политика история политическая_философия
# subj_011:  биомедицина клетка онкология белки биофизика кардиология клеточная_биология мембрана медицина старение
# subj_012:  право история социология_права Англия юриспруденция политическая_философия судопроизводство полиция судебная_система власть
# subj_013:  астрономия астрофизика звезды галактика космос Вселенная нейтронные_звезды радиотелескопы звездное_скопление телескоп
# subj_014:  Россия общество черные_дыры экзопланета глобализация историческая_память атмосфера Малевич_Казимир праздник Украина
# subj_015:  человек нейропсихология музыка инфляция банковская_система теория_игр дефляция адаптация макроэкономика финансовый_рынок
# subj_016:  медицина биология кардиология кровеносная_система нейродегенеративное_заболевание доказательная_медицина хирургия медицинская_диагностика плацебо антибиотики
# subj_017:  социология социология_повседневности теория_фреймов Зиммель_Георг Латур_Брюно фрейм Гоффман_Эрвинг фрейм-анализ Шюц_Альфред эпистемология
# subj_018:  биология генетика белки ДНК белок молекулярная_биология биоинформатика микробиология геном секвенирование
# subj_019:  язык лингвистика русский_язык филология грамматика полевая_лингвистика диалект речь лингвистическая_компаративистика английский_язык
# subj_020:  культура культурология массовая_культура театр театроведение ритуал Шекспир_Уильям СССР драматургия культура_повседневности
# subj_021:  технологии человек биоэтика смерть старение томография речь оружие социокультурная_антропология сосуды
# subj_022:  социология общество Дюркгейм_Эмиль Вебер_Макс этнометодология Гоффман_Эрвинг микросоциология идентичность медиа социология_науки
# subj_023:  Россия Большой_адронный_коллайдер общество симметрия частица история_науки опрос_общественного_мнения бозон_Хиггса Сколково класс
# subj_052:  психология принятие_решений детство теория_принятия_решений поведение_человека психоанализ психика поведенческая_экономика теория_игр педагогика
# subj_053:  астрофизика физика_элементарных_частиц кварк физика протон черные_дыры космические_лучи элементарная_частица адрон телескоп
# subj_054:  антропология археология Африка этнография майя Мезоамерика Латинская_Америка конкиста Мексика Испания
# subj_055:  математика геометрия алгебра термодинамика топология суперкомпьютеры Филдсовская_премия энтропия графы сингулярность
# subj_056:  ген геном ДНК биоинформатика генетика секвенирование биология молекулярная_биология биотехнологии СПИД
# subj_057:  биология бактерии микробиология иммунитет вирус клетка иммунология бактериофаги прокариоты туберкулез
# subj_058:  история Франция Французская_революция_XVIII_века Новое_время Екатерина_II монархия Шмитт_Карл Просвещение феминизм Робеспьер_Максимилиан
# subj_059:  химия углерод нанотехнологии химический_элемент таблица_Менделеева Максвелл_Джеймс фотохимия ковалентная_связь фуллерены миф
# subj_060:  СССР история демократия историческая_память политическая_теория терроризм Гоббс_Томас Штраус_Лео история_России архивоведение
# subj_061:  микробиология экология география микробы геология Земля климат бактерии палеоботаника биотехнологии
# subj_062:  физика электрон квантовая_теория_поля история_науки частица физика_элементарных_частиц квантовая_гравитация физика_твердого_тела атом конфайнмент
# subj_063:  экономика экономическое_развитие экономическое_неравенство коррупция США промышленность финансовый_кризис экономический_рост новая_институциональная_экономика финансовый_рынок
# subj_064:  наука образование академическая_среда история_науки социология_науки Российская_академия_наук диссертация Мертон_Роберт индекс_цитирования Академия_наук
# subj_065:  антропология человек антропогенез происхождение_человека расоведение неандерталец Homo_sapiens физическая_антропология вулканизм раса
# subj_066:  квантовая_физика квантовые_технологии фотоны оптика электроника физика свет нанофотоника квантовый_компьютер квантовая_оптика
# subj_067:  биология палеонтология биотехнологии ГМО растения ботаника флора палеобиология коэволюция палеофитоценоз
# subj_068:  Россия общество Смит_Адам расизм геронтология сообщество альтруизм праздник симметрия Менделеев_Дмитрий
# subj_069:  философия Кант_Иммануил история_философии марксизм Маркс_Карл Платон немецкая_классическая_философия политическая_философия Фуко_Мишель Гегель_Георг_Вильгельм_Фридрих

# %% [markdown]
# ### Генерация json

# %%
import json

# %%
psis = [psi1, psi2]
tokens = [tokens0, tokens1, tokens2]
levels = [level0, level1, level2]
max_level = 2
def gen_json_level(level, topic, supertopic=None, threshold=0.05, num_tokens=5):
    if level == max_level:
        return {"size": int(psis[-1].values[topic, supertopic]*10000), 
                "name": ", ".join(tokens[-1][levels[-1].topic_names[topic]][:num_tokens]).encode("utf-8")}
    json = {"name": ", ".join(tokens[level][levels[level].topic_names[topic]][:num_tokens]).encode("utf-8"),
           "children": [gen_json_level(level+1, subtopic, topic) 
                        for subtopic in range(levels[level+1].num_topics)
                        if psis[level].values[subtopic, topic] > threshold]}
    if level != 0:
        json["size"] = int(psis[level-1].values[topic, supertopic]*10000)
    return json

# %%
h_json = {"children": [gen_json_level(0, subtopic) for subtopic in range(level0.num_topics)]}

# %%
with open("./hier.json", "w") as fout:
    json.dump(h_json, fout, ensure_ascii=False)
