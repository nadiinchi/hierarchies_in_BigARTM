# %%
import artm
import os
import glob
import sys

# %%
sys.path.append("D:/PTM/code/BigAltHier")

# %%
import hierarchy_functions
reload(hierarchy_functions)
# Out:
# <module 'hierarchy_functions' from 'D:/PTM/code/BigAltHier\hierarchy_functions.py'>

# %%
data_path_UCI = 'ngramm/pymorphy/UCI_trimmed/'
data_path_batches = 'ngramm/pymorphy/batches/'
if len(glob.glob(data_path_batches + "/*.batch")) < 1:
    batch_vectorizer = artm.BatchVectorizer(collection_name='postnauka', data_format='bow_uci', \
                data_path = data_path_UCI, batch_size = 200, target_folder=data_path_batches)
else:
    batch_vectorizer = artm.BatchVectorizer(data_path=data_path_batches, data_format='batches')

# %%
def get_topic_names(topicNum):
    n_bckgrnd = 0
    n_subj = topicNum-n_bckgrnd
    topics_bckgrnd = [u'background_'+str(i).zfill(3) for i in range(n_bckgrnd)]
    topics_subj = [u'subj_'+str(i).zfill(3) for i in range(n_subj)]
    topic_names = topics_bckgrnd + topics_subj
    return topic_names

# %%
class_ids={'ngramm':1.0, 'projects':1.0, 'category':1, 'author': 5.0, 'post_tag':5.0}

# %%
regularizers_list = []

regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiCatReg',class_ids=['category'],tau=0.05))
regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiAuthorReg',class_ids=['author'],tau=0.05))
regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiTagReg',class_ids=['post_tag'],tau=0.05))
regularizers_list.append(artm.DecorrelatorPhiRegularizer(name='DecorrPhiReg',class_ids=['ngramm'],tau=50000))

regularizers_list.append(artm.SmoothSparsePhiRegularizer(name='SPPhiNgrammRegSubj',
                                                         class_ids=['ngramm'],
                                                         #topic_names=topics_subj,
                                                         tau=0.01))
regularizers_list.append(artm.SmoothSparseThetaRegularizer(name='SmoothThetaRegSubj',
                                                           #topic_names=topics_subj,
                                                           tau=0.01))

# %%
# quality measures of models
scores_list = []
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreNgrammSubj',
                                         class_id='ngramm',
                                         #topic_names=topics_subj
                                        ))
scores_list.append(artm.SparsityThetaScore(name='SparsityScoreThetaSubj',
                                           #topic_names=topics_subj
                                          ))

scores_list.append(artm.SparsityPhiScore(name='SparsityScoreCat', class_id='category'))
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreAuthor', class_id='author'))
scores_list.append(artm.SparsityPhiScore(name='SparsityScoreTag', class_id='post_tag'))
scores_list.append(artm.TopTokensScore(name='TopTokensScoreNgramm', class_id='ngramm', num_tokens=10))
scores_list.append(artm.TopTokensScore(name='TopTokensTag', class_id='post_tag', num_tokens=10))
scores_list.append(artm.TopicKernelScore(name='TopicKernelNgramm', class_id='ngramm', probability_mass_threshold=0.25))
scores_list.append(artm.PerplexityScore(name='PerplexityScore', class_ids=['ngramm']))

# %%
dict_path = 'ngramm/pymorphy/UCI_trimmed/dictionary.txt'
if not os.path.isfile(dict_path):
    dictionary = artm.Dictionary('dictionary')
    dictionary.gather(batch_vectorizer.data_path)
    dictionary.save_text(dict_path)
else:
    dictionary = artm.Dictionary('dictionary')
    dictionary.load_text(dict_path)

# %%
topicNum0 = 11
model = artm.ARTM(num_topics=topicNum0,
                  topic_names=get_topic_names(topicNum0),
                  class_ids=class_ids,
                  regularizers=regularizers_list,
                  scores=scores_list)
model.initialize(dictionary=dictionary)

# %%
model.fit_offline(batch_vectorizer, num_collection_passes=30)

# %%
tokens = model.score_tracker["TopTokensTag"].last_tokens
for topic_name in model.topic_names:
    print topic_name + ': ',
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# subj_000:  медицина мозг биология нейробиология нейрон психология онкология нейрофизиология биомедицина старение
# subj_001:  биология эволюция психология антропология человек когнитивная_психология мышление палеонтология этология антропогенез
# subj_002:  экономика Россия политика общество государство США политология СССР социология история
# subj_003:  история культура история_России Средневековье христианство Россия религия Европа Русь Франция
# subj_004:  язык лингвистика филология культура русский_язык литература фольклор литературоведение мифология фольклористика
# subj_005:  астрономия астрофизика звезды космос Вселенная галактика химия Земля черные_дыры Солнце
# subj_006:  образование наука история_науки университет культура Россия философия математика школа кино
# subj_007:  физика физика_элементарных_частиц квантовая_физика элементарная_частица кварк бозон_Хиггса атом Большой_адронный_коллайдер Стандартная_модель космология
# subj_008:  социология философия культура общество город культурология социология_повседневности юриспруденция право Кант_Иммануил
# subj_009:  технологии информационные_технологии математика интернет искусственный_интеллект информатика наука computer_science робототехника робот
# subj_010:  биология генетика ДНК клетка геном ген микробиология медицина белки химия

# %%
topicNum1 = 50
level1 = hierarchy_functions.ARTM_Level(model, phi_batch_weight=10**3, 
                                        num_topics=topicNum1, 
                                        topic_names=get_topic_names(topicNum1), 
                                         class_ids=class_ids,
                                          regularizers=regularizers_list,
                                           scores=scores_list,
                                            num_document_passes=1, 
                                             cache_theta=True, seed=124)

# %%
level1.initialize(dictionary=dictionary)
level1.fit_offline(batch_vectorizer, num_collection_passes=30)

# %%
tokens = level1.score_tracker["TopTokensTag"].last_tokens
for topic_name in level1.topic_names:
    print topic_name + ': ',
    for word in tokens[topic_name]:    
        print word,
    print
# Out:
# subj_000:  геология социология_права палеоботаника логика компьютерное_моделирование судопроизводство ботаника полиция судебная_система сейсмология
# subj_001:  математика сон геометрия топология кибернетика алгебра нейрон статистика сомнология атомная_энергетика
# subj_002:  история история_России СССР историография Первая_мировая_война Вторая_мировая_война культурная_политика Великая_Отечественная_война Древняя_Ирландия империя
# subj_003:  психология литература фольклор когнитивная_психология литературоведение фольклористика внимание народная_культура сказка зрение
# subj_004:  информационные_технологии информатика computer_science интеллект социальные_сети информационная_безопасность атмосфера машинное_обучение хранение_данных компьютерные_сети
# subj_005:  массовая_культура культура культурология кино гендер кинематограф феминизм постмодернизм паракинематограф Жижек_Славой
# subj_006:  звезды астрономия галактика астрофизика черные_дыры нейтронные_звезды космос звездное_скопление радиотелескопы телескоп
# subj_007:  физика электрон оптика электроника квантовая_теория_поля фотоны графен свет частица органическая_электроника
# subj_008:  философия Кант_Иммануил поэзия личность этика немецкая_классическая_философия аналитическая_философия философия_сознания биоэтика русская_философия
# subj_009:  социология этология поведение_животных этнометодология музыка адаптивное_поведение приматы субкультуры опрос_общественного_мнения утопия
# subj_010:  наука социология_науки академическая_среда философия_науки Латур_Брюно эпистемология Российская_академия_наук диссертация Поппер_Карл научный_метод
# subj_011:  человек антропогенез происхождение_человека антропология неандерталец антибиотики физическая_антропология Homo_sapiens фармакология биология
# subj_012:  филология Древняя_Греция античность языкознание праязык риторика Пушкин_Александр доказательная_медицина Гомер языковые_семьи
# subj_013:  культура искусство искусствоведение Англия театр театроведение авангард история_повседневности Шекспир_Уильям дворянство
# subj_014:  социология Дюркгейм_Эмиль Вебер_Макс марксизм Маркс_Карл социальная_структура Гоффман_Эрвинг микросоциология Зиммель_Георг мода
# subj_015:  гравитация принятие_решений общая_теория_относительности теория_принятия_решений идеология гравитационные_волны специальная_теория_относительности демография мораль квантовая_гравитация
# subj_016:  генетика ДНК ген геном биология РНК геномика мутация генетическое_заболевание секвенирование
# subj_017:  Вселенная астрофизика космология астрономия реликтовое_излучение темная_материя космическая_инфляция Большой_взрыв темная_энергия рентгеновское_излучение
# subj_018:  государство власть Рим инквизиция Древний_Рим история Римская_империя поведенческая_экономика Средневековый_суд ведовство
# subj_019:  религия христианство история востоковедение археология Кавказ ислам цивилизация Византия Сирия
# subj_020:  материаловедение Нобелевская_премия кристалл кристаллография полимеры спин Ньютон_Исаак металлы музей механика
# subj_021:  биология микробиология микробы иммунитет вирус иммунология геном вирусология СПИД Уотсон_Джеймс
# subj_022:  бактерии биология молекула молекулярная_биология клетка клеточная_биология бактериофаги терроризм флуоресцентные_белки мембрана
# subj_023:  мозг нейробиология нейрон нейрофизиология память нейропсихология биология сознание стресс психофизиология
# subj_024:  Средневековье Европа история христианство католицизм религиоведение медиевистика папство Ирландия Фома_Аквинский
# subj_025:  медицина биомедицина онкология биофизика неврология рак раковые_клетки разработка_лекарств кровеносная_система нейродегенеративное_заболевание
# subj_026:  квантовая_физика квантовая_механика магнитное_поле квантовые_технологии физика сверхпроводимость лазер квантовый_компьютер фотоны нанофотоника
# subj_027:  язык лингвистика зоология коммуникация зоопсихология лингвистическая_компаративистика лексика русский_язык корпусная_лингвистика словарь
# subj_028:  физика_элементарных_частиц элементарная_частица кварк бозон_Хиггса физика Большой_адронный_коллайдер Стандартная_модель симметрия нейтрино коллайдер
# subj_029:  политика политология биоинформатика Сталин_Иосиф демократия Египет ислам секвенирование политический_режим Великобритания
# subj_030:  Россия Китай Япония письменность теория_игр Украина древний_мир синология Соловьев_Владимир славянофильство
# subj_031:  Франция медиа Новое_время Французская_революция_XVIII_века культура_повседневности социальная_мобильность промышленность модернизация монархия конституция
# subj_032:  право Германия юриспруденция римское_право история_права историческая_память национал-социализм Гитлер_Адольф Холокост история_Германии
# subj_033:  астрономия космос Солнце Солнечная_система планета экзопланета Марс планеты метеорит астрофизика
# subj_034:  химия экология география органическая_химия биохимия углерод энергетика климат катализ вулканизм
# subj_035:  город урбанистика городское_пространство социология_пространства архитектура Москва глобализация экономическое_развитие экономическое_неравенство сообщество
# subj_036:  США Русь ритуал Скандинавия обряд библиотека праздник Рюриковичи династия бракосочетание
# subj_037:  экономика финансовый_рынок рынок финансовый_кризис поведение_человека инфляция безработица рынок_труда банковская_система коррупция
# subj_038:  биология эволюция палеонтология старение Дарвин_Чарльз эволюционная_биология теория_эволюции абиогенез естественный_отбор метаболизм
# subj_039:  общество идентичность нация детство миграция гражданство социальная_психология мультикультурализм педагогика национальность
# subj_040:  биология клетка белки биотехнологии стволовые_клетки генная_инженерия белок ГМО эукариоты регенеративная_медицина
# subj_041:  русский_язык социология_повседневности грамматика речь полевая_лингвистика диалект теория_фреймов фонетика английский_язык фрейм
# subj_042:  Земля искусственный_интеллект робототехника робот технологии океан кислород Мировой_океан экобиотехнология парниковый_эффект
# subj_043:  политическая_философия история_философии Аристотель Платон кардиология либерализм Сократ Фуко_Мишель русская_литература политическая_теория
# subj_044:  технологии интернет физиология эмоции нейронные_сети психотерапия психиатрия психоанализ суперкомпьютеры Фрейд_Зигмунд
# subj_045:  история_науки атом этнография национализм этнос Эйнштейн_Альберт нейтрон водород коренные_народы радиоактивность
# subj_046:  образование университет мышление школа психология_мышления ЕГЭ социология_образования Гумбольдт_Вильгельм Шеллинг_Фридрих Болонский_процесс
# subj_047:  антропология мифология миф расоведение раса Толкин_Дж._Р._Р. смерть Индия австралоиды социальная_антропология
# subj_048:  физика нанотехнологии наноматериалы энергия спектроскопия электромагнетизм нанотрубки солнечная_энергия масс-спектрометрия метаматериалы
# subj_049:  история Африка майя Мезоамерика Испания Латинская_Америка конкиста Мексика Южная_Америка Северная_Америка

# %%
level1.cache_theta = False

# %%
psi = level1.get_psi()

# %%
psi
# Out:
#           subj_000  subj_001  subj_002  subj_003  subj_004  subj_005  \
# subj_000      0.02      0.02      0.02      0.02      0.02      0.02
# subj_001      0.02      0.02      0.02      0.02      0.02      0.02
# subj_002      0.02      0.02      0.02      0.02      0.02      0.02
# subj_003      0.02      0.02      0.02      0.02      0.02      0.02
# subj_004      0.02      0.02      0.02      0.02      0.02      0.02
# subj_005      0.02      0.02      0.02      0.02      0.02      0.02
# subj_006      0.02      0.02      0.02      0.02      0.02      0.02
# subj_007      0.02      0.02      0.02      0.02      0.02      0.02
# subj_008      0.02      0.02      0.02      0.02      0.02      0.02
# subj_009      0.02      0.02      0.02      0.02      0.02      0.02
# subj_010      0.02      0.02      0.02      0.02      0.02      0.02
# subj_011      0.02      0.02      0.02      0.02      0.02      0.02
# subj_012      0.02      0.02      0.02      0.02      0.02      0.02
# subj_013      0.02      0.02      0.02      0.02      0.02      0.02
# subj_014      0.02      0.02      0.02      0.02      0.02      0.02
# subj_015      0.02      0.02      0.02      0.02      0.02      0.02
# subj_016      0.02      0.02      0.02      0.02      0.02      0.02
# subj_017      0.02      0.02      0.02      0.02      0.02      0.02
# subj_018      0.02      0.02      0.02      0.02      0.02      0.02
# subj_019      0.02      0.02      0.02      0.02      0.02      0.02
# subj_020      0.02      0.02      0.02      0.02      0.02      0.02
# subj_021      0.02      0.02      0.02      0.02      0.02      0.02
# subj_022      0.02      0.02      0.02      0.02      0.02      0.02
# subj_023      0.02      0.02      0.02      0.02      0.02      0.02
# subj_024      0.02      0.02      0.02      0.02      0.02      0.02
# subj_025      0.02      0.02      0.02      0.02      0.02      0.02
# subj_026      0.02      0.02      0.02      0.02      0.02      0.02
# subj_027      0.02      0.02      0.02      0.02      0.02      0.02
# subj_028      0.02      0.02      0.02      0.02      0.02      0.02
# subj_029      0.02      0.02      0.02      0.02      0.02      0.02
# subj_030      0.02      0.02      0.02      0.02      0.02      0.02
# subj_031      0.02      0.02      0.02      0.02      0.02      0.02
# subj_032      0.02      0.02      0.02      0.02      0.02      0.02
# subj_033      0.02      0.02      0.02      0.02      0.02      0.02
# subj_034      0.02      0.02      0.02      0.02      0.02      0.02
# subj_035      0.02      0.02      0.02      0.02      0.02      0.02
# subj_036      0.02      0.02      0.02      0.02      0.02      0.02
# subj_037      0.02      0.02      0.02      0.02      0.02      0.02
# subj_038      0.02      0.02      0.02      0.02      0.02      0.02
# subj_039      0.02      0.02      0.02      0.02      0.02      0.02
# subj_040      0.02      0.02      0.02      0.02      0.02      0.02
# subj_041      0.02      0.02      0.02      0.02      0.02      0.02
# subj_042      0.02      0.02      0.02      0.02      0.02      0.02
# subj_043      0.02      0.02      0.02      0.02      0.02      0.02
# subj_044      0.02      0.02      0.02      0.02      0.02      0.02
# subj_045      0.02      0.02      0.02      0.02      0.02      0.02
# subj_046      0.02      0.02      0.02      0.02      0.02      0.02
# subj_047      0.02      0.02      0.02      0.02      0.02      0.02
# subj_048      0.02      0.02      0.02      0.02      0.02      0.02
# subj_049      0.02      0.02      0.02      0.02      0.02      0.02
#
#           subj_006  subj_007  subj_008  subj_009  subj_010
# subj_000      0.02      0.02      0.02      0.02      0.02
# subj_001      0.02      0.02      0.02      0.02      0.02
# subj_002      0.02      0.02      0.02      0.02      0.02
# subj_003      0.02      0.02      0.02      0.02      0.02
# subj_004      0.02      0.02      0.02      0.02      0.02
# subj_005      0.02      0.02      0.02      0.02      0.02
# subj_006      0.02      0.02      0.02      0.02      0.02
# subj_007      0.02      0.02      0.02      0.02      0.02
# subj_008      0.02      0.02      0.02      0.02      0.02
# subj_009      0.02      0.02      0.02      0.02      0.02
# subj_010      0.02      0.02      0.02      0.02      0.02
# subj_011      0.02      0.02      0.02      0.02      0.02
# subj_012      0.02      0.02      0.02      0.02      0.02
# subj_013      0.02      0.02      0.02      0.02      0.02
# subj_014      0.02      0.02      0.02      0.02      0.02
# subj_015      0.02      0.02      0.02      0.02      0.02
# subj_016      0.02      0.02      0.02      0.02      0.02
# subj_017      0.02      0.02      0.02      0.02      0.02
# subj_018      0.02      0.02      0.02      0.02      0.02
# subj_019      0.02      0.02      0.02      0.02      0.02
# subj_020      0.02      0.02      0.02      0.02      0.02
# subj_021      0.02      0.02      0.02      0.02      0.02
# subj_022      0.02      0.02      0.02      0.02      0.02
# subj_023      0.02      0.02      0.02      0.02      0.02
# subj_024      0.02      0.02      0.02      0.02      0.02
# subj_025      0.02      0.02      0.02      0.02      0.02
# subj_026      0.02      0.02      0.02      0.02      0.02
# subj_027      0.02      0.02      0.02      0.02      0.02
# subj_028      0.02      0.02      0.02      0.02      0.02
# subj_029      0.02      0.02      0.02      0.02      0.02
# subj_030      0.02      0.02      0.02      0.02      0.02
# subj_031      0.02      0.02      0.02      0.02      0.02
# subj_032      0.02      0.02      0.02      0.02      0.02
# subj_033      0.02      0.02      0.02      0.02      0.02
# subj_034      0.02      0.02      0.02      0.02      0.02
# subj_035      0.02      0.02      0.02      0.02      0.02
# subj_036      0.02      0.02      0.02      0.02      0.02
# subj_037      0.02      0.02      0.02      0.02      0.02
# subj_038      0.02      0.02      0.02      0.02      0.02
# subj_039      0.02      0.02      0.02      0.02      0.02
# subj_040      0.02      0.02      0.02      0.02      0.02
# subj_041      0.02      0.02      0.02      0.02      0.02
# subj_042      0.02      0.02      0.02      0.02      0.02
# subj_043      0.02      0.02      0.02      0.02      0.02
# subj_044      0.02      0.02      0.02      0.02      0.02
# subj_045      0.02      0.02      0.02      0.02      0.02
# subj_046      0.02      0.02      0.02      0.02      0.02
# subj_047      0.02      0.02      0.02      0.02      0.02
# subj_048      0.02      0.02      0.02      0.02      0.02
# subj_049      0.02      0.02      0.02      0.02      0.02
